# %%
                                         ####Descriptive Analytics for Numerical Columns####
# Import  dataset

# %%
import pandas as pd
df = pd.read_csv("sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
print(df.shape),print(df.columns)
# Out:
# (450, 13)
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')
# (None, None)

# %%
df.info
# Out:
# <bound method DataFrame.info of            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
# ...

# %%
#####  Numarical columns
numerical_cols = df.select_dtypes(include=['number'])
print("Numerical columns:")
print(numerical_cols.columns)
# Out:
# Numerical columns:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
###Mean Value
mean_values = numerical_cols.mean()
mean_values
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
####Median value
median_values = numerical_cols.median()
median_values
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
###Mode Value 
mode_values = numerical_cols.mode().iloc[0]  
mode_values
# Out:
# Volume                   3.000000
# Avg Price              400.000000
# Total Sales Value    24300.000000
# Discount Rate (%)        5.007822
# Discount Amount         69.177942
# Net Sales Value        326.974801
# Name: 0, dtype: float64

# %%
###Standard deviation 
std_values = numerical_cols.std()
std_values
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
### Data Frame
statistics_df = pd.DataFrame({'Mean':mean_values,
                              'Median':median_values,
                              'Mode':mode_values,
                              'Standard Deviation':std_values
                             })
print(statistics_df)
# Out:
#                            Mean       Median          Mode  Standard Deviation
# Volume                 5.066667     4.000000      3.000000            4.231602
# Avg Price          10453.433333  1450.000000    400.000000        18079.904840
# Total Sales Value  33812.835556  5700.000000  24300.000000        50535.074173
# Discount Rate (%)     15.155242    16.577766      5.007822            4.220602
# Discount Amount     3346.499424   988.933733     69.177942         4509.902963
# Net Sales Value    30466.336131  4677.788059    326.974801        46358.656624

# %%
####Data Visualization####
###Histograms Plot

# %%
import matplotlib.pyplot as plt
numerical_cols.hist(figsize=(14, 8), bins=10, edgecolor='black')
plt.suptitle("Histograms for Numerical Columns", fontsize=16)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Select numerical columns
numerical_cols = df.select_dtypes(include='number')
for col in numerical_cols.columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], bins=10, kde=True, color='skyblue', edgecolor='black')
# Calculate skewness
    skewness = df[col].skew()
    plt.title(f'Histogram of {col} (Skewness = {skewness:.2f})')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.axvline(df[col].mean(), color='red', linestyle='--', label='Mean')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
#### Box Plot of Numarical columns
import seaborn as sns
for col in numerical_cols.columns:
    plt.figure(figsize=(6, 1.5))
    sns.boxplot(x=df[col], color='skyblue')
    plt.title(f'Boxplot for {col}')
    plt.xlabel(col)
    plt.grid(True, axis='x')
    plt.tight_layout()
    plt.show()

# %%
###Categorical columns
categorical_cols = df.select_dtypes(include='object').columns
print("Categorical columns:", list(categorical_cols))
# Out:
# Categorical columns: ['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model']

# %%
###Categorical columns of Categorical columns
import seaborn as sns
for col in categorical_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col], color='skyblue')
    plt.title(f'Boxplot for {col}')
    plt.xlabel(col)
    plt.grid(True, axis='x')
    plt.tight_layout()
    plt.show()

# %%
### Bar Chart Analysis for Categorical Column 
import matplotlib.pyplot as plt
for col in categorical_cols:
    plt.figure(figsize=(6, 4))
    df[col].value_counts().plot(kind='bar', color='orange', edgecolor='black')
    plt.title(f'Bar Chart - {col}')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
####Standardization of Numerical Variables

# %%
from sklearn.preprocessing import StandardScaler
numerical_cols.hist(figsize=(12, 10), edgecolor='black',color='red')
plt.suptitle("Before Standardization")
plt.tight_layout()
plt.show()
####Standardize using z-score
scaler = StandardScaler()
standardized_array = scaler.fit_transform(numerical_cols)
df_standardized = pd.DataFrame(standardized_array, columns=numerical_cols.columns)
df_standardized.hist(figsize=(12, 10),edgecolor='black', color='lightgreen')
plt.suptitle("After Standardization")
plt.tight_layout()
plt.show()

# %%
###Conversion of Categorical Data into Dummy Variables
categorical_col= pd.get_dummies(df,columns=categorical_cols,drop_first=False)
print(categorical_col.head())
# Out:
#    Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      15      12100             181500          11.654820     21153.498820
# 1      10      10100             101000          11.560498     11676.102961
# 2       7      16100             112700           9.456886     10657.910157
# 3       6      20100             120600           6.935385      8364.074702
# 4       3       8100              24300          17.995663      4372.946230
#
#    Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0    160346.501180             True            False            False
# 1     89323.897039             True            False            False
# 2    102042.089843             True            False            False
# 3    112235.925298             True            False            False
# 4     19927.053770             True            False            False
#
#    Date_04-04-2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# ...

# %%
####################################Conclusion#######################################
#1.Descriptive statistics revealed skewness in Sales and Profit,while Discounts showed low variability.
#2.Visualizations confirmed the presence of outliers in Sales and Profit and highlighted uneven distribution across categories.
#3.Standardization successfully scaled numerical variables to a uniform range (mean=0, std=1).
#4.One-hot encoding transformed categorical features into machine-learning ready binary variables.
#Overall, the dataset is now cleaned, standardized, and encoded, 
#making it suitable for further predictive modeling and analysis.
                                      ### Thanks You ###
