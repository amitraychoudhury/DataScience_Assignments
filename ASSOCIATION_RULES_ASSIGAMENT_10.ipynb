# %%
# Import necessary libraries
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Data Preprocessing 
# Load the dataset
df_raw = pd.read_excel("Online retail.xlsx", header=None)
df_raw
# Out:
#                                                       0
# 0     shrimp,almonds,avocado,vegetables mix,green gr...
# 1                                burgers,meatballs,eggs
# 2                                               chutney
# 3                                        turkey,avocado
# 4     mineral water,milk,energy bar,whole wheat rice...
# ...                                                 ...
# 7496                      butter,light mayo,fresh bread
# 7497  burgers,frozen vegetables,eggs,french fries,ma...
# 7498                                            chicken
# 7499                                 escalope,green tea
# 7500    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7501 rows x 1 columns]

# %%
df_raw.info
# Out:
# <bound method DataFrame.info of                                                       0
# 0     shrimp,almonds,avocado,vegetables mix,green gr...
# 1                                burgers,meatballs,eggs
# 2                                               chutney
# 3                                        turkey,avocado
# 4     mineral water,milk,energy bar,whole wheat rice...
# ...                                                 ...
# 7496                      butter,light mayo,fresh bread
# 7497  burgers,frozen vegetables,eggs,french fries,ma...
# 7498                                            chicken
# 7499                                 escalope,green tea
# 7500    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7501 rows x 1 columns]>

# %%
df_raw.head()
# Out:
#                                                    0
# 0  shrimp,almonds,avocado,vegetables mix,green gr...
# 1                             burgers,meatballs,eggs
# 2                                            chutney
# 3                                     turkey,avocado
# 4  mineral water,milk,energy bar,whole wheat rice...

# %%
df_raw.columns = ['Basket']
df_raw.columns
# Out:
# Index(['Basket'], dtype='object')

# %%
# Handle missing values: remove empty baskets
df_clean = df_raw.dropna(subset=['Basket'])
df_clean
# Out:
#                                                  Basket
# 0     shrimp,almonds,avocado,vegetables mix,green gr...
# 1                                burgers,meatballs,eggs
# 2                                               chutney
# 3                                        turkey,avocado
# 4     mineral water,milk,energy bar,whole wheat rice...
# ...                                                 ...
# 7496                      butter,light mayo,fresh bread
# 7497  burgers,frozen vegetables,eggs,french fries,ma...
# 7498                                            chicken
# 7499                                 escalope,green tea
# 7500    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7501 rows x 1 columns]

# %%
# Remove duplicate baskets
df_clean = df_clean.drop_duplicates()
df_clean
# Out:
#                                                  Basket
# 0     shrimp,almonds,avocado,vegetables mix,green gr...
# 1                                burgers,meatballs,eggs
# 2                                               chutney
# 3                                        turkey,avocado
# 4     mineral water,milk,energy bar,whole wheat rice...
# ...                                                 ...
# 7493  burgers,salmon,pancakes,french fries,frozen sm...
# 7494  turkey,burgers,dessert wine,shrimp,pasta,tomat...
# 7496                      butter,light mayo,fresh bread
# 7497  burgers,frozen vegetables,eggs,french fries,ma...
# 7500    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [5176 rows x 1 columns]

# %%
# Convert each basket string into a list of items
baskets = df_clean['Basket'].apply(lambda x: [item.strip() for item in str(x).split(',') if item.strip()])
baskets
# Out:
# 0       [shrimp, almonds, avocado, vegetables mix, gre...
# 1                              [burgers, meatballs, eggs]
# 2                                               [chutney]
# 3                                       [turkey, avocado]
# 4       [mineral water, milk, energy bar, whole wheat ...
#                               ...
# 7493    [burgers, salmon, pancakes, french fries, froz...
# 7494    [turkey, burgers, dessert wine, shrimp, pasta,...
# 7496                    [butter, light mayo, fresh bread]
# 7497    [burgers, frozen vegetables, eggs, french frie...
# 7500    [eggs, frozen smoothie, yogurt cake, low fat y...
# Name: Basket, Length: 5176, dtype: object

# %%
# Convert list of baskets into one-hot encoded DataFrame
te = TransactionEncoder()
te
# Out:
# TransactionEncoder()

# %%
te_ary = te.fit(baskets.tolist()).transform(baskets.tolist())
te_ary
# Out:
# array([[ True,  True, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False]])

# %%
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)
df_encoded
# Out:
#       almonds  antioxydant juice  asparagus  avocado  babies food  bacon  \
# 0        True               True      False     True        False  False
# 1       False              False      False    False        False  False
# 2       False              False      False    False        False  False
# 3       False              False      False     True        False  False
# 4       False              False      False    False        False  False
# ...       ...                ...        ...      ...          ...    ...
# 5171    False              False      False    False        False  False
# 5172    False              False      False    False        False  False
# 5173    False              False      False    False        False  False
# 5174    False              False      False    False        False  False
# 5175    False              False      False    False        False  False
#
#       barbecue sauce  black tea  blueberries  body spray  ...  turkey  \
# 0              False      False        False       False  ...   False
# 1              False      False        False       False  ...   False
# 2              False      False        False       False  ...   False
# 3              False      False        False       False  ...    True
# 4              False      False        False       False  ...   False
# ...              ...        ...          ...         ...  ...     ...
# 5171           False      False        False       False  ...   False
# 5172           False      False        False       False  ...    True
# 5173           False      False        False       False  ...   False
# 5174           False      False        False       False  ...   False
# 5175           False      False        False       False  ...   False
#
#       vegetables mix  water spray  white wine  whole weat flour  \
# 0               True        False       False              True
# 1              False        False       False             False
# 2              False        False       False             False
# 3              False        False       False             False
# 4              False        False       False             False
# ...              ...          ...         ...               ...
# 5171           False        False       False             False
# 5172           False        False       False             False
# 5173           False        False       False             False
# 5174           False        False       False             False
# 5175           False        False       False             False
#
#       whole wheat pasta  whole wheat rice   yams  yogurt cake  zucchini
# 0                 False             False   True        False     False
# 1                 False             False  False        False     False
# 2                 False             False  False        False     False
# 3                 False             False  False        False     False
# 4                 False              True  False        False     False
# ...                 ...               ...    ...          ...       ...
# 5171              False             False  False        False     False
# 5172              False              True  False        False     False
# 5173              False             False  False        False     False
# 5174              False             False  False        False     False
# 5175              False             False  False         True     False
#
# [5176 rows x 119 columns]

# %%
#Association Rule Mining
# Set support threshold 0.5
min_support = 0.05
min_support
# Out:
# 0.05

# %%
frequent_itemsets = apriori(df_encoded, min_support=min_support, use_colnames=True)
frequent_itemsets
# Out:
#      support                            itemsets
# 0   0.113794                           (burgers)
# 1   0.103555                              (cake)
# 2   0.054869                         (champagne)
# 3   0.083849                           (chicken)
# 4   0.205178                         (chocolate)
# 5   0.060665                           (cookies)
# 6   0.071870                       (cooking oil)
# 7   0.208076                              (eggs)
# 8   0.083849                          (escalope)
# 9   0.192620                      (french fries)
# 10  0.059312                       (fresh bread)
# 11  0.084815                   (frozen smoothie)
# 12  0.129830                 (frozen vegetables)
# 13  0.070131                     (grated cheese)
# 14  0.169243                         (green tea)
# 15  0.135819                       (ground beef)
# 16  0.066461                     (herb & pepper)
# 17  0.065301                             (honey)
# 18  0.095054                    (low fat yogurt)
# 19  0.170015                              (milk)
# 20  0.299845                     (mineral water)
# 21  0.087713                         (olive oil)
# 22  0.125193                          (pancakes)
# 23  0.057573                            (salmon)
# 24  0.098918                            (shrimp)
# 25  0.070904                              (soup)
# 26  0.229521                         (spaghetti)
# 27  0.091963                          (tomatoes)
# 28  0.083269                            (turkey)
# 29  0.077859                  (whole wheat rice)
# 30  0.073223          (mineral water, chocolate)
# 31  0.055835              (chocolate, spaghetti)
# 32  0.070131               (mineral water, eggs)
# 33  0.051391                   (spaghetti, eggs)
# 34  0.050425  (mineral water, frozen vegetables)
# 35  0.058733        (ground beef, mineral water)
# 36  0.055835            (ground beef, spaghetti)
# 37  0.067813               (milk, mineral water)
# 38  0.050039                   (milk, spaghetti)
# 39  0.085008          (mineral water, spaghetti)

# %%
# Print the top frequent itemsets
print("Most frequent itemsets:")
print(frequent_itemsets.sort_values('support', ascending=False).head())
# Out:
# Most frequent itemsets:
#      support         itemsets
# 20  0.299845  (mineral water)
# 26  0.229521      (spaghetti)
# 7   0.208076           (eggs)
# 4   0.205178      (chocolate)
# 9   0.192620   (french fries)

# %%
# Set thresholds for rules
min_confidence = 0.3 
min_lift = 1.2

# %%
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=min_confidence)
rules
# Out:
#            antecedents      consequents  antecedent support  \
# 0          (chocolate)  (mineral water)            0.205178
# 1               (eggs)  (mineral water)            0.208076
# 2  (frozen vegetables)  (mineral water)            0.129830
# 3        (ground beef)  (mineral water)            0.135819
# 4        (ground beef)      (spaghetti)            0.135819
# 5               (milk)  (mineral water)            0.170015
# 6          (spaghetti)  (mineral water)            0.229521
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.299845  0.073223    0.356874  1.190193               1.0
# 1            0.299845  0.070131    0.337047  1.124070               1.0
# 2            0.299845  0.050425    0.388393  1.295310               1.0
# 3            0.299845  0.058733    0.432432  1.442184               1.0
# 4            0.229521  0.055835    0.411095  1.791102               1.0
# 5            0.299845  0.067813    0.398864  1.330231               1.0
# 6            0.299845  0.085008    0.370370  1.235204               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.011701    1.088674       0.201051  0.169575   0.081451    0.300537
# 1  0.007741    1.056115       0.139377  0.160194   0.053134    0.285470
# 2  0.011496    1.144778       0.262000  0.132960   0.126468    0.278281
# 3  0.018008    1.233606       0.354795  0.155818   0.189368    0.314154
# 4  0.024661    1.308326       0.511102  0.180400   0.235664    0.327181
# 5  0.016835    1.164718       0.299103  0.168669   0.141423    0.312512
# 6  0.016187    1.112010       0.247141  0.191304   0.100728    0.326938

# %%
# Filter rules to include only those with lift > threshold
rules = rules[rules['lift'] > min_lift]
rules
# Out:
#            antecedents      consequents  antecedent support  \
# 2  (frozen vegetables)  (mineral water)            0.129830
# 3        (ground beef)  (mineral water)            0.135819
# 4        (ground beef)      (spaghetti)            0.135819
# 5               (milk)  (mineral water)            0.170015
# 6          (spaghetti)  (mineral water)            0.229521
#
#    consequent support   support  confidence      lift  representativity  \
# 2            0.299845  0.050425    0.388393  1.295310               1.0
# 3            0.299845  0.058733    0.432432  1.442184               1.0
# 4            0.229521  0.055835    0.411095  1.791102               1.0
# 5            0.299845  0.067813    0.398864  1.330231               1.0
# 6            0.299845  0.085008    0.370370  1.235204               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 2  0.011496    1.144778       0.262000  0.132960   0.126468    0.278281
# 3  0.018008    1.233606       0.354795  0.155818   0.189368    0.314154
# 4  0.024661    1.308326       0.511102  0.180400   0.235664    0.327181
# 5  0.016835    1.164718       0.299103  0.168669   0.141423    0.312512
# 6  0.016187    1.112010       0.247141  0.191304   0.100728    0.326938

# %%
#Analysis & Interpretation
# Display top 10 rules sorted by lift
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
      .sort_values('lift', ascending=False)
      .head(10))
# Out:
#            antecedents      consequents   support  confidence      lift
# 4        (ground beef)      (spaghetti)  0.055835    0.411095  1.791102
# 3        (ground beef)  (mineral water)  0.058733    0.432432  1.442184
# 5               (milk)  (mineral water)  0.067813    0.398864  1.330231
# 2  (frozen vegetables)  (mineral water)  0.050425    0.388393  1.295310
# 6          (spaghetti)  (mineral water)  0.085008    0.370370  1.235204

# %%
# Additional insights: For example, rules involving 'eggs'
eggs_rules = rules[(rules['antecedents'].apply(lambda x: 'eggs' in x)) |
                   (rules['consequents'].apply(lambda x: 'eggs' in x))]
eggs_rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []

# %%
print(eggs_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []

# %%
#Save to Csv File
rules.to_csv('association_rules_output.csv', index=False)

# %%
###Interview Questions:
#1.
###What is lift and why is it important in Association rules?
#Lift measures how much more likely items A and B are bought together compared to if they were independent.
#(Lift(A → B) = Confidence(A → B)/Support(B)
#L>1 → Positive association → A and B are bought together more often than by chance.
#L= → No association → A and B are independent.
#L<1 → Negative association → Buying A reduces the chance of buying B.
#2.
###What is support and Confidence. How do you calculate them?
#Support:frequency
#Support(A)=Transactions containing A/Total Transactions
#Confidence:reliability of rule.
#Confidence(A→B)=Support(A∪B)/Support(A)
#3.
###What are some limitations or challenges of Association rules mining?
#Association rule mining generates too many rules, is sensitive to thresholds, ignores purchase order/time,
#misses rare items, and can be computationally expensive.
